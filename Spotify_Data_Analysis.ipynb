# %%
#Importing Libraries

import pandas as pd
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
#Reading and Exploring Data Shape
df = pd.read_csv("C:/Users/domin/OneDrive/Documents/Spotify/Spotify data.csv")
df.head()
df_copy = df.copy()

# %%
df.shape
# Out:
# (114000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB

# %%
df.duplicated().any()
# Out:
# False

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.dropna()
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music
#
# [113999 rows x 20 columns]

# %%
df.nunique()
# Out:
# track_id            89741
# artists             31437
# album_name          46582
# track_name          73603
# popularity            101
# duration_ms         50697
# explicit                2
# danceability         1174
# energy               2083
# key                    12
# loudness            19480
# mode                    2
# speechiness          1489
# acousticness         5061
# instrumentalness     5346
# liveness             1722
# valence              1790
# tempo               45653
# time_signature          5
# track_genre           114
# dtype: int64

# %%
#Changing explicit attribute to numerical

df = pd.get_dummies(data=df, columns=['explicit'], drop_first=True)

# %%
df['explicit_True'] = df['explicit_True'].astype(int)
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  danceability  energy  \
# 0                      Comedy          73       230666         0.676  0.4610
# 1            Ghost - Acoustic          55       149610         0.420  0.1660
# 2              To Begin Again          57       210826         0.438  0.3590
# 3  Can't Help Falling In Love          71       201933         0.266  0.0596
# 4                     Hold On          82       198853         0.618  0.4430
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -6.746     0       0.1430        0.0322          0.000001    0.3580
# 1    1   -17.235     1       0.0763        0.9240          0.000006    0.1010
# 2    0    -9.734     1       0.0557        0.2100          0.000000    0.1170
# 3    0   -18.515     1       0.0363        0.9050          0.000071    0.1320
# 4    2    -9.681     1       0.0526        0.4690          0.000000    0.0829
#
#    valence    tempo  time_signature track_genre  explicit_True
# 0    0.715   87.917               4    acoustic              0
# 1    0.267   77.489               4    acoustic              0
# 2    0.120   76.332               4    acoustic              0
# 3    0.143  181.740               3    acoustic              0
# 4    0.167  119.949               4    acoustic              0

# %%
#Analysing Distribution of target variable(popularity)

sns.displot(data=df, x='popularity', kind='kde')

# %%
# lis = ['speechiness', 'speechiness_log']
# col = 1

# sns.displot(data=df,
#             x='speechiness',
#             row=0,
#             col=1,
#             kind='kde',
#             )
# plt.title('Before Log transformation')

# sns.displot(data=df,
#             x='speechiness_log',
#             row=0,
#             col=0,
#             kind='kde')
# plt.title('After Log transformation')

# %%
sns.pairplot(data=df,
             y_vars='popularity')

# %%
sns.countplot(data=df,
              x='explicit_True')
# Out:
# <Axes: xlabel='explicit_True', ylabel='count'>

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  danceability  energy  \
# 0                      Comedy          73       230666         0.676  0.4610
# 1            Ghost - Acoustic          55       149610         0.420  0.1660
# 2              To Begin Again          57       210826         0.438  0.3590
# 3  Can't Help Falling In Love          71       201933         0.266  0.0596
# 4                     Hold On          82       198853         0.618  0.4430
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -6.746     0       0.1430        0.0322          0.000001    0.3580
# 1    1   -17.235     1       0.0763        0.9240          0.000006    0.1010
# 2    0    -9.734     1       0.0557        0.2100          0.000000    0.1170
# 3    0   -18.515     1       0.0363        0.9050          0.000071    0.1320
# 4    2    -9.681     1       0.0526        0.4690          0.000000    0.0829
#
#    valence    tempo  time_signature track_genre  explicit_True
# 0    0.715   87.917               4    acoustic              0
# 1    0.267   77.489               4    acoustic              0
# 2    0.120   76.332               4    acoustic              0
# 3    0.143  181.740               3    acoustic              0
# 4    0.167  119.949               4    acoustic              0

# %%
skew_variables = df.skew(numeric_only=True).to_frame().rename(columns={0: 'skew'})
highly_skewed = skew_variables[skew_variables['skew'] > 0.75]
lis = highly_skewed.index.to_list()

# Add specific columns correctly
lis.extend(['speechiness', 'duration_ms'])

# Apply log transform safely (e.g., add 1 to avoid log(0))
for col in lis:
    df[col] = np.log(df[col] + 1)

# %%
genre_group = (
    df.groupby('track_genre', as_index=False)
      .mean(numeric_only=True)          # ignore object columns automatically
      [['track_genre', 'popularity']]   # keep the column you care about
      .sort_values('popularity', ascending=False)
      .head(10) 
)
print(genre_group)
# Out:
#    track_genre  popularity
# 81    pop-film      59.283
# 65       k-pop      56.896
# 15       chill      53.651
# 94         sad      52.379
# 44      grunge      49.594
# 55      indian      49.539
# 5        anime      48.772
# 33         emo      48.128
# 97   sertanejo      47.866
# 80         pop      47.576

# %%
sns.displot(data=df,
            x='tempo',
            kind='hist',
            bins=np.arange(0,210, 10))

# %%
sns.countplot(data=df,
              x='track_genre')
# Out:
# <Axes: xlabel='track_genre', ylabel='count'>

# %%
plt.xlim(40,60)
sns.barplot(data=genre_group,
            y='track_genre',
            x='popularity',
            color = sns.color_palette()[0])
# Out:
# <Axes: xlabel='popularity', ylabel='track_genre'>

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  danceability  energy  \
# 0                      Comedy          73     2.591421         0.676  0.4610
# 1            Ghost - Acoustic          55     2.558451         0.420  0.1660
# 2              To Begin Again          57     2.584661         0.438  0.3590
# 3  Can't Help Falling In Love          71     2.581405         0.266  0.0596
# 4                     Hold On          82     2.580242         0.618  0.4430
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -6.746     0     0.125448        0.0322          0.000001  0.306013
# 1    1   -17.235     1     0.070952        0.9240          0.000006  0.096219
# 2    0    -9.734     1     0.052786        0.2100          0.000000  0.110647
# 3    0   -18.515     1     0.035036        0.9050          0.000071  0.123986
# 4    2    -9.681     1     0.049993        0.4690          0.000000  0.079643
#
#    valence    tempo  time_signature track_genre  explicit_True
# 0    0.715   87.917               4    acoustic            0.0
# 1    0.267   77.489               4    acoustic            0.0
# 2    0.120   76.332               4    acoustic            0.0
# 3    0.143  181.740               3    acoustic            0.0
# 4    0.167  119.949               4    acoustic            0.0

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.xlim(50,100)
top_20_albums = df.groupby(by=['album_name'], as_index=False).size().sort_values('size', ascending=False).head(20)
sns.barplot(data=top_20_albums,
            y= 'album_name',
            x='size',
            color=sns.color_palette()[0])

plt.title('TOP 20 ALBUMS')
top_20_albums
# Out:
#                                  album_name  size
# 2591             Alternative Christmas 2022   195
# 13326           Feliz Cumpleaños con Perreo   184
# 23969                                 Metal   143
# 15898                Halloween con perreito   123
# 15886                  Halloween Party 2022   115
# 37218            The Complete Hank Williams   111
# 13407                       Fiesta portatil   110
# 14058                     Frescura y Perreo   106
# 12430                 Esto me suena a Farra   105
# 28711                   Perreo en Halloween   103
# 27296                      On air 70's Hits   102
# 30096           Queda poco para la PAES 2.0   101
# 30913                  Reggeaton Imperdible    98
# 15881                Halloween Metal Nights    95
# 16985                Homecoming Latin Party    95
# 11659                El perreo es el futuro    94
# 15445                         Greatest Hits    93
# 3334   Arbeitsmusik Herbst/Winter 2022/2023    93
# 15949              Hans Zimmer: Epic Scores    91
# 11198   EDM Gaming Music Autumn/Winter 2022    90

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  danceability  energy  \
# 0                      Comedy          73     2.591421         0.676  0.4610
# 1            Ghost - Acoustic          55     2.558451         0.420  0.1660
# 2              To Begin Again          57     2.584661         0.438  0.3590
# 3  Can't Help Falling In Love          71     2.581405         0.266  0.0596
# 4                     Hold On          82     2.580242         0.618  0.4430
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -6.746     0     0.125448        0.0322          0.000001  0.306013
# 1    1   -17.235     1     0.070952        0.9240          0.000006  0.096219
# 2    0    -9.734     1     0.052786        0.2100          0.000000  0.110647
# 3    0   -18.515     1     0.035036        0.9050          0.000071  0.123986
# 4    2    -9.681     1     0.049993        0.4690          0.000000  0.079643
#
#    valence    tempo  time_signature track_genre  explicit_True
# 0    0.715   87.917               4    acoustic            0.0
# 1    0.267   77.489               4    acoustic            0.0
# 2    0.120   76.332               4    acoustic            0.0
# 3    0.143  181.740               3    acoustic            0.0
# 4    0.167  119.949               4    acoustic            0.0

# %%
top_20_songs = df.sort_values('popularity', ascending=False).head(20)[['track_name','artists','popularity']]
top_20_songs.head(5)
# Out:
#                                   track_name                  artists  \
# 20001              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras
# 81051              Unholy (feat. Kim Petras)     Sam Smith;Kim Petras
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap;Quevedo
# 81210                        I'm Good (Blue)  David Guetta;Bebe Rexha
# 89411                             La Bachata            Manuel Turizo
#
#        popularity
# 20001         100
# 81051         100
# 51664          99
# 81210          98
# 89411          98

# %%
sns.barplot(data=top_20_songs,
            y='track_name',
            x='popularity',

            )
# Out:
# <Axes: xlabel='popularity', ylabel='track_name'>

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  danceability  energy  \
# 0                      Comedy          73     2.591421         0.676  0.4610
# 1            Ghost - Acoustic          55     2.558451         0.420  0.1660
# 2              To Begin Again          57     2.584661         0.438  0.3590
# 3  Can't Help Falling In Love          71     2.581405         0.266  0.0596
# 4                     Hold On          82     2.580242         0.618  0.4430
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    1    -6.746     0     0.125448        0.0322          0.000001  0.306013
# 1    1   -17.235     1     0.070952        0.9240          0.000006  0.096219
# 2    0    -9.734     1     0.052786        0.2100          0.000000  0.110647
# 3    0   -18.515     1     0.035036        0.9050          0.000071  0.123986
# 4    2    -9.681     1     0.049993        0.4690          0.000000  0.079643
#
#    valence    tempo  time_signature track_genre  explicit_True
# 0    0.715   87.917               4    acoustic            0.0
# 1    0.267   77.489               4    acoustic            0.0
# 2    0.120   76.332               4    acoustic            0.0
# 3    0.143  181.740               3    acoustic            0.0
# 4    0.167  119.949               4    acoustic            0.0

# %%
db = df_copy.sample(100)
db
# Out:
#        Unnamed: 0                track_id  \
# 34036       34036  7wKwX3QFmx3icbH7iKVPe4
# 29296       29296  4PaO2lfUtNOso7ruTbPovz
# 26622       26622  7GFJa5vM69cAGtoJtRJdEc
# 79318       79318  2l3gQ8Zv1KlGqyE6B4ntPC
# 75354       75354  3X743fO7cwXAugb1zYVNjG
# ...           ...                     ...
# 16962       16962  42SGnHloMGNJB4zGBPPs5Z
# 27565       27565  2BsQkkcmbO2MRVijjl25Dy
# 55514       55514  2aUZaQ3ZFxh63KpSBfHNnZ
# 19196       19196  0hBN7k2AAmbc0mM4cUAmQH
# 35727       35727  4yRemvJmZaDapoeMXaOYcN
#
#                                                  artists  \
# 34036                                         Kabir Cafe
# 29296                 ILLENIUM;Teddy Swims;Mike Williams
# 26622                                       Drowsy Teddy
# 79318                                        OneRepublic
# 75354                                     Ronan Hardiman
# ...                                                  ...
# 16962  Wolfgang Amadeus Mozart;Wiener Mozart Ensemble...
# 27565                              Metrik;Rothwell;S.P.Y
# 55514                   Pritam;Arjun Kanungo;Lisa Mishra
# 19196                                      Kenny Chesney
# 35727                              Pisadinha do Vaqueiro
#
#                                              album_name  \
# 34036                                         Panchrang
# 29296                 All That Really Matters (Remixes)
# 26622  Ted Heads West!:10 Country and Western Lullabies
# 79318                                    Human (Deluxe)
# 75354               Michael Flatley's Lord Of The Dance
# ...                                                 ...
# 16962                       Mozart: A Night of Classics
# 27565                           Hospitality In The Park
# 55514                                   The Sky Is Pink
# 19196                 Burn Burn Burn - Hot Country Hits
# 35727                                Vaqueiro Sabe Amar
#
#                                             track_name  popularity  \
# 34036                           Matkar Maya Ko Ahankar          54
# 29296    All That Really Matters - Mike Williams Remix          54
# 26622                       Tied Together with a Smile          21
# 79318                                         Distance          51
# 75354                                            Gypsy          46
# ...                                                ...         ...
# 16962  Six German Dances, K.567: No. 2 in E Flat Major          10
# 27565                          We Got It - S.P.Y Remix          18
# 55514                                      Nadaaniyaan          48
# 19196                               Everyone She Knows           0
# 35727                                 Estilo Capa Loka          39
#
#        duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 34036       365672     False         0.796  0.5170  ...    -6.289     1
# 29296       201465     False         0.623  0.8970  ...    -5.270     0
# 26622       111578     False         0.323  0.0248  ...   -15.226     1
# 79318       180352     False         0.611  0.7660  ...    -5.686     1
# 75354       130440     False         0.632  0.5150  ...   -12.226     0
# ...            ...       ...           ...     ...  ...       ...   ...
# 16962        88960     False         0.370  0.1940  ...   -16.954     1
# 27565       297451     False         0.453  0.8830  ...    -4.955     0
# 55514       258983     False         0.677  0.8230  ...    -4.997     1
# 19196       204986     False         0.659  0.6820  ...    -5.045     1
# 35727       160235     False         0.721  0.8950  ...    -3.917     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 34036       0.0257      0.613000          0.000013    0.1380   0.6140
# 29296       0.1710      0.052900          0.001910    0.1300   0.5810
# 26622       0.0400      0.996000          0.849000    0.1050   0.5030
# 79318       0.0634      0.112000          0.000007    0.1950   0.7130
# 75354       0.0307      0.389000          0.928000    0.4070   0.5220
# ...            ...           ...               ...       ...      ...
# 16962       0.0330      0.955000          0.910000    0.3370   0.6740
# 27565       0.0412      0.000598          0.188000    0.3700   0.0799
# 55514       0.0375      0.109000          0.000006    0.1650   0.1740
# 19196       0.0293      0.009920          0.000000    0.1590   0.6640
# 35727       0.0432      0.485000          0.005000    0.0265   0.9620
#
#          tempo  time_signature    track_genre
# 34036  107.475               1           folk
# 29296  124.066               4        dubstep
# 26622   72.449               5         disney
# 79318  150.956               4          piano
# 75354  113.947               4        new-age
# ...        ...             ...            ...
# 16962   86.199               4      classical
# 27565  174.011               4  drum-and-bass
# 55514  128.010               4         indian
# 19196  109.022               4        country
# 35727  168.205               4          forro
#
# [100 rows x 21 columns]

# %%
db[db['duration_ms'] > 180000]
# Out:
#        Unnamed: 0                track_id  \
# 34036       34036  7wKwX3QFmx3icbH7iKVPe4
# 29296       29296  4PaO2lfUtNOso7ruTbPovz
# 79318       79318  2l3gQ8Zv1KlGqyE6B4ntPC
# 70298       70298  4UD5xrQI4nKftCje1y5Te9
# 74099       74099  5FTkJggemdWf4Kr6CyWJv1
# ...           ...                     ...
# 69549       69549  42vzIZr96agNvV98Tzg79L
# 13880       13880  1WoTST0ikXUttdtNTmp7zf
# 27565       27565  2BsQkkcmbO2MRVijjl25Dy
# 55514       55514  2aUZaQ3ZFxh63KpSBfHNnZ
# 19196       19196  0hBN7k2AAmbc0mM4cUAmQH
#
#                                                  artists  \
# 34036                                         Kabir Cafe
# 29296                 ILLENIUM;Teddy Swims;Mike Williams
# 79318                                        OneRepublic
# 70298                                         Eason Chan
# 74099                                         Kid Abelha
# ...                                                  ...
# 69549  Sujatha;Noel James;Srinivas;Sivanesan;Ganga Sr...
# 13880                                    DJ Sneak;Demuir
# 27565                              Metrik;Rothwell;S.P.Y
# 55514                   Pritam;Arjun Kanungo;Lisa Mishra
# 19196                                      Kenny Chesney
#
#                               album_name  \
# 34036                          Panchrang
# 29296  All That Really Matters (Remixes)
# 79318                     Human (Deluxe)
# 70298                        The Line-Up
# 74099                        Ressaquinha
# ...                                  ...
# 69549                             Bombay
# 13880          Made In Miami Rewind 2018
# 27565            Hospitality In The Park
# 55514                    The Sky Is Pink
# 19196  Burn Burn Burn - Hot Country Hits
#
#                                            track_name  popularity  \
# 34036                          Matkar Maya Ko Ahankar          54
# 29296   All That Really Matters - Mike Williams Remix          54
# 79318                                        Distance          51
# 70298                                            明年今日          54
# 74099  Na rua, na chuva, na fazenda (Casinha de sapé)           0
# ...                                               ...         ...
# 69549                               Idhu Annai Bhoomi          25
# 13880                             1 For The Muchachos           5
# 27565                         We Got It - S.P.Y Remix          18
# 55514                                     Nadaaniyaan          48
# 19196                              Everyone She Knows           0
#
#        duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 34036       365672     False         0.796   0.517  ...    -6.289     1
# 29296       201465     False         0.623   0.897  ...    -5.270     0
# 79318       180352     False         0.611   0.766  ...    -5.686     1
# 70298       206117     False         0.670   0.397  ...   -10.870     1
# 74099       224373     False         0.754   0.495  ...   -10.966     1
# ...            ...       ...           ...     ...  ...       ...   ...
# 69549       207425     False         0.525   0.409  ...   -12.350     0
# 13880       414229     False         0.791   0.873  ...    -7.894     0
# 27565       297451     False         0.453   0.883  ...    -4.955     0
# 55514       258983     False         0.677   0.823  ...    -4.997     1
# 19196       204986     False         0.659   0.682  ...    -5.045     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 34036       0.0257      0.613000          0.000013    0.1380   0.6140
# 29296       0.1710      0.052900          0.001910    0.1300   0.5810
# 79318       0.0634      0.112000          0.000007    0.1950   0.7130
# 70298       0.0417      0.710000          0.000000    0.1100   0.2140
# 74099       0.0322      0.106000          0.003160    0.0685   0.8070
# ...            ...           ...               ...       ...      ...
# 69549       0.0418      0.068300          0.000005    0.1200   0.2960
# 13880       0.0811      0.000124          0.791000    0.5440   0.4370
# 27565       0.0412      0.000598          0.188000    0.3700   0.0799
# 55514       0.0375      0.109000          0.000006    0.1650   0.1740
# 19196       0.0293      0.009920          0.000000    0.1590   0.6640
#
#          tempo  time_signature    track_genre
# 34036  107.475               1           folk
# 29296  124.066               4        dubstep
# 79318  150.956               4          piano
# 70298  123.969               4       mandopop
# 74099  140.244               4            mpb
# ...        ...             ...            ...
# 69549  146.970               4          malay
# 13880  123.999               4  chicago-house
# 27565  174.011               4  drum-and-bass
# 55514  128.010               4         indian
# 19196  109.022               4        country
#
# [65 rows x 21 columns]

# %%
from scipy.stats import binom
prob = 1 - binom.cdf(71,100,0.5)
print(prob * 100)
# Out:
# 0.000628957500836691

# %%
df_copy.head(2)
# Out:
#    Unnamed: 0                track_id       artists        album_name  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV   Gen Hoshino            Comedy
# 1           1  4qPNDBW1i3p13qLCt0Ki3A  Ben Woodward  Ghost (Acoustic)
#
#          track_name  popularity  duration_ms  explicit  danceability  energy  \
# 0            Comedy          73       230666     False         0.676   0.461
# 1  Ghost - Acoustic          55       149610     False         0.420   0.166
#
#    ...  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0  ...    -6.746     0       0.1430        0.0322          0.000001     0.358
# 1  ...   -17.235     1       0.0763        0.9240          0.000006     0.101
#
#    valence   tempo  time_signature  track_genre
# 0    0.715  87.917               4     acoustic
# 1    0.267  77.489               4     acoustic
#
# [2 rows x 21 columns]

# %%
df.describe()
# Out:
#           popularity    duration_ms   danceability         energy  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean       33.238535       2.584618       0.566800       0.641383
# std        22.305078       0.029949       0.173542       0.251529
# min         0.000000       0.000000       0.000000       0.000000
# 25%        17.000000       2.570105       0.456000       0.472000
# 50%        35.000000       2.585401       0.580000       0.685000
# 75%        50.000000       2.600778       0.695000       0.854000
# max       100.000000       2.801620       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.072125
# std         3.559987       5.029337       0.480709       0.068174
# min         0.000000     -49.531000       0.000000       0.000000
# 25%         2.000000     -10.013000       0.000000       0.034663
# 50%         5.000000      -7.004000       1.000000       0.046637
# 75%         8.000000      -5.003000       1.000000       0.077997
# max        11.000000       4.532000       1.000000       0.516107
#
#         acousticness  instrumentalness       liveness        valence  \
# count  114000.000000     114000.000000  114000.000000  114000.000000
# mean        0.314910          0.116556       0.183164       0.474068
# std         0.332523          0.224796       0.138420       0.259261
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.016900          0.000000       0.093490       0.260000
# 50%         0.169000          0.000042       0.123986       0.464000
# 75%         0.598000          0.047837       0.241376       0.683000
# max         0.996000          0.693147       0.693147       0.995000
#
#                tempo  time_signature  explicit_True
# count  114000.000000   114000.000000  114000.000000
# mean      122.147837        3.904035       0.059264
# std        29.978197        0.432621       0.193822
# min         0.000000        0.000000       0.000000
# 25%        99.218750        4.000000       0.000000
# 50%       122.017000        4.000000       0.000000
# 75%       140.071000        4.000000       0.000000
# max       243.372000        5.000000       0.693147

# %%
sns.boxplot(data=df,
            x='danceability')
plt.title('Danceability Boxplot')
# Out:
# Text(0.5, 1.0, 'Danceability Boxplot')

# %%
top_artists =df_copy.groupby('artists').max()['popularity'].to_frame().sort_values('popularity', ascending=False).head(10)
top_artists.head(10)
# Out:
#                             popularity
# artists
# Sam Smith;Kim Petras               100
# Bizarrap;Quevedo                    99
# David Guetta;Bebe Rexha             98
# Manuel Turizo                       98
# Bad Bunny;Chencho Corleone          97
# Bad Bunny                           97
# OneRepublic                         96
# Chris Brown                         96
# Harry Styles                        95
# Bad Bunny;Bomba Estéreo             95

# %%
plt.xlim(90,101)

sns.barplot(data=top_artists,
            x='popularity',
            y=top_artists.index,
            color = sns.color_palette()[0])

plt.title('TOP 10 ARTISTS', fontsize=16)
# Out:
# Text(0.5, 1.0, 'TOP 10 ARTISTS')
